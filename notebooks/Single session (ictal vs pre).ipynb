# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyedflib
import mne

import random 
import re
from tqdm import tqdm

DB_PATH = './db/v1.5.1/'

# %%
'''
Load data from one file
'''

file_dir = './db/v1.5.1/edf/train/01_tcp_ar/091/00009104/s006_2014_09_23'
EVENTS_FILE = './train/01_tcp_ar/091/00009104/s006_2014_09_23/00009104_s006_t002.tse'

def data_load(data_file, selected_channels=[]):

    try:
        # use the reader to get an EdfReader file
        f = pyedflib.EdfReader(data_file)

        # get the names of the signals
        channel_names = f.getSignalLabels()
        # get the sampling frequencies of each signal
        channel_freq = f.getSampleFrequencies()
        
        # get a list of the EEG channels
        if len(selected_channels) == 0:
            selected_channels = channel_names

        # make an empty file of 0's
        sigbufs = np.zeros((f.getNSamples()[0],len(selected_channels)))
        # for each of the channels in the selected channels
        for i, channel in enumerate(selected_channels):
            try:
              # add the channel data into the array
              sigbufs[:, i] = f.readSignal(channel_names.index(channel))
            
            except:
              ValueError
              sigbufs[:, i] = np.nan


        # turn to a pandas df and save a little space
        df = pd.DataFrame(sigbufs, columns = selected_channels)#.astype('float32')

        # get equally increasing numbers upto the length of the data depending
        # on the length of the data divided by the sampling frequency
        index_increase = np.linspace(0,
                                      len(df)/channel_freq[0],
                                      len(df), endpoint=False)

        seconds = index_increase
        
        # make a column the timestamp
        df['Time'] = seconds

        # make the time stamp the index
        df = df.set_index('Time')

        # name the columns as channel
        df.columns.name = 'Channel'

        return df, channel_freq[0]

    except:
        OSError
        return pd.DataFrame(), None

seiz_edf_name = EVENTS_FILE.split('/')[-1][:-3]+'edf'
seiz_edf_file = file_dir +'/'+ seiz_edf_name
seiz_data, seiz_freq = data_load(seiz_edf_file)

print(seiz_edf_file)
display(seiz_data.shape)
# Out:
# ./db/v1.5.1/edf/train/01_tcp_ar/091/00009104/s006_2014_09_23/00009104_s006_t002.edf
# (284000, 31)

# %%
def mne_object(data, freq, events_tse = pd.DataFrame()):
  # create an mne info file with meta data about the EEG
  info = mne.create_info(ch_names=list(data.columns), 
                         sfreq=freq, 
                         ch_types=['eeg']*data.shape[-1])
  
  # data needs to be in volts rather than in microvolts
  data = data.apply(lambda x: x*1e-6)
  # transpose the data
  data_T = data.transpose()
  
  # create raw mne object
  raw = mne.io.RawArray(data_T, info)

  if not events_tse.empty:

    raw.set_annotations(mne.Annotations(events_tse['Start'],
                                          events_tse['End'] - events_tse['Start'],
                                          events_tse['Code']))

  return raw

seiz_events_name = EVENTS_FILE.split('/')[-1]
events_tse = pd.read_csv(file_dir+'/'+seiz_events_name, 
                             skiprows=1,
                             sep = ' ',
                             header=None,
                             names =['Start', 'End', 'Code', 'Certainty'])

tuh_mne = mne_object(seiz_data, seiz_freq, events_tse)

print(file_dir+'/'+seiz_events_name)
# Out:
# Creating RawArray with float64 data, n_channels=31, n_times=284000
#     Range : 0 ... 283999 =      0.000 ...  1135.996 secs
# Ready.
# ./db/v1.5.1/edf/train/01_tcp_ar/091/00009104/s006_2014_09_23/00009104_s006_t002.tse

# %%
plot_kwargs = {
    'scalings': dict(eeg=20e-5),   # zooms the plot out
    'highpass': 0.5,              # filters out low frequencies
    'lowpass': 70.,                # filters out high frequencies
    'show_scrollbars': False,
    'show': True
}


for class_code in events_tse['Code'].unique():
    code_events = events_tse.where(events_tse['Code'] == class_code).dropna()
    fig = tuh_mne.plot(start = code_events.sample(random_state = 0)['Start'].values[0], 
                    duration = 30, **plot_kwargs)
# Out:
# Setting up band-pass filter from 0.5 - 70 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 0.50, 70.00 Hz: -6.02, -6.02 dB
# <MNEBrowseFigure size 432x288 with 4 Axes>
# Setting up band-pass filter from 0.5 - 70 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 0.50, 70.00 Hz: -6.02, -6.02 dB
# <MNEBrowseFigure size 432x288 with 4 Axes>

# %%
# Get similar channels
channel_keeps = ['EEG F8-REF', 'EEG T5-REF', 'EEG F7-REF', 'EEG FP1-REF', 'EEG P3-REF', 'EEG P4-REF', 'EEG FZ-REF', 'EEG T4-REF', 'EEG O2-REF', 'EEG F3-REF', 'EEG T6-REF', 'EEG CZ-REF', 'EEG FP2-REF', 'EEG O1-REF', 'EEG C4-REF', 'EEG T3-REF', 'EEG PZ-REF', 'EEG F4-REF', 'EEG C3-REF']


print(channel_keeps)
# Out:
# ['EEG F8-REF', 'EEG T5-REF', 'EEG F7-REF', 'EEG FP1-REF', 'EEG P3-REF', 'EEG P4-REF', 'EEG FZ-REF', 'EEG T4-REF', 'EEG O2-REF', 'EEG F3-REF', 'EEG T6-REF', 'EEG CZ-REF', 'EEG FP2-REF', 'EEG O1-REF', 'EEG C4-REF', 'EEG T3-REF', 'EEG PZ-REF', 'EEG F4-REF', 'EEG C3-REF']

# %%
ATT_START = 0
ATT_END = 0

import chardet
def create_events(file_name, df, code = None):

    data_y = pd.Series(index=df.index)
    data_y.name = 'Events'
    
    events_tse = pd.read_csv(file_name,
                             skiprows=1,
                             sep = ' ',
                             header=None,
                             names =['Start', 'End', 'Code', 'Certainty'])
    
    data_y = data_y.fillna('bckg')
    
    
    for pos, row in events_tse.iterrows():
        # if you want to manually set the code
        if code != None:
          if row['Code'] == code:
              data_y[row['Start']:row['End']] = code
        # let it be the code it is in the event file
        else:
          data_y[row['Start']:row['End']] = row['Code']

    return data_y

# %%
# Read files into df and create events series

file_ID = EVENTS_FILE.split('/')[-1][:-4]
# we use the above to get the file directory this file is in
pat_file_dir = 'edf/' + '/'.join(EVENTS_FILE.split('/')[1:-1])
   
file_path = DB_PATH+pat_file_dir+'/'+file_ID+'.edf'
#print(file_path)
pat_ID = EVENTS_FILE.split('/')[-3]

# load data
raw_data, freq = data_load(file_path, channel_keeps)
   
if raw_data.empty:
    print('Skipped: '+file_ID)
else:
    raw_events = create_events(DB_PATH+pat_file_dir+'/'+file_ID+'.tse', raw_data)
    # change to integer representation
    #raw_events = raw_events.replace(int_code)
# Out:
# <ipython-input-6-000e68478807>:7: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   data_y = pd.Series(index=df.index)

# %%
# Replace labels in pd series, 0 for no seizure and 1 for seizure
raw_events = raw_events.replace('bckg',0)
raw_events = raw_events.replace('gnsz',1)

print(raw_events)
display(raw_data)
# Out:
# Time
# 0.000       0
# 0.004       0
# 0.008       0
# 0.012       0
# 0.016       0
#            ..
# 1135.980    0
# 1135.984    0
# 1135.988    0
# 1135.992    0
# 1135.996    0
# Name: Events, Length: 284000, dtype: int64
# Channel   EEG F8-REF  EEG T5-REF  EEG F7-REF  EEG FP1-REF  EEG P3-REF  \
# Time
# 0.000     -19.738714   -5.182645  -35.131339   -25.259982    1.175178
# 0.004     -17.229047    8.034935  -23.084937   -23.586870   13.556202
# 0.008     -11.373157   19.412092  -16.894425   -22.081070   20.415959
# 0.012     -14.217447   15.396625  -24.088804   -28.271582   16.400491
# 0.016     -12.711646    5.357956  -29.777382   -31.115871    6.529134
# ...              ...         ...         ...          ...         ...
# 1135.980  -28.606204  -21.077203  -32.956294    -2.505667  -24.088804
# 1135.984  -32.119738  -26.933093  -38.310250   -35.131339  -26.096537
# 1135.988  -28.940827  -25.929226  -35.967894   -10.536602  -20.742581
# 1135.992  -27.435026  -26.096537  -39.314117    10.879224  -15.890558
# 1135.996  -21.244514  -24.088804  -27.936960     7.365690  -14.719380
#
# Channel   EEG P4-REF  EEG FZ-REF  EEG T4-REF  EEG O2-REF  EEG F3-REF  \
# Time
# 0.000       2.848289  -27.100404   -7.525001  -35.633272  -45.002696
# 0.004      12.217713  -33.290916    2.011734  -21.579137  -42.325717
# 0.008      17.404358  -33.290916   10.377290  -14.552069  -38.979495
# 0.012      15.731247  -35.800583    8.202246  -17.563669  -48.516229
# 0.016      10.879224  -32.454360    3.350223   -8.361557  -50.691274
# ...              ...         ...         ...         ...         ...
# 1135.980   -8.194246  -22.583003  -15.388625  -29.442760  -26.765782
# 1135.984  -15.054002  -21.244514  -20.407959  -32.788983  -13.882824
# 1135.988  -16.894425  -21.077203  -21.746448  -28.271582  -14.217447
# 1135.992  -20.073336  -23.754181  -21.077203  -30.781249  -20.073336
# 1135.996  -20.407959  -19.236781  -18.400225  -25.259982  -27.769649
#
# Channel   EEG T6-REF  EEG CZ-REF  EEG FP2-REF  EEG O1-REF  EEG C4-REF  \
# Time
# 0.000       0.840556  -10.369290   -18.400225  -59.056831   -7.859623
# 0.004      14.727380   -4.680712   -22.917626  -46.675807   -5.851890
# 0.008      24.598737    1.175178   -20.909892  -29.610071   -1.836422
# 0.012      21.419825   -1.501800   -19.236781  -42.493029    0.505933
# 0.016      12.552335   -6.019201   -16.225180  -49.520096    3.015600
# ...              ...         ...          ...         ...         ...
# 1135.980  -10.034668  -27.100404   -40.819917  -42.493029  -18.734847
# 1135.984  -17.229047  -29.610071   -41.321851  -23.419559  -20.909892
# 1135.988  -18.400225  -28.104271   -15.221313  -13.380891  -19.906025
# 1135.992  -20.575270  -29.777382    -4.848023  -21.579137  -15.388625
# 1135.996  -20.407959  -27.602337    -7.190379  -14.384758   -9.700046
#
# Channel   EEG T3-REF  EEG PZ-REF  EEG F4-REF  EEG C3-REF
# Time
# 0.000     -13.213580   -5.182645  -24.925359  -28.271582
# 0.004       0.171311    4.521401  -29.442760  -21.746448
# 0.008      10.711913   11.548468  -28.606204  -14.552069
# 0.012       6.361823    7.700312  -31.450494  -21.077203
# 0.016      -3.007600    0.673245  -26.263848  -27.435026
# ...              ...         ...         ...         ...
# 1135.980  -34.796716  -26.765782  -13.380891  -26.431160
# 1135.984  -39.983362  -31.115871  -16.727114  -31.283182
# 1135.988  -36.135205  -29.610071  -34.796716  -24.590737
# 1135.992  -31.785116  -30.613938  -46.843118  -20.909892
# 1135.996  -28.271582  -28.773515  -39.314117  -22.081070
#
# [284000 rows x 19 columns]

# %%
# Change to an array
data_X = raw_data.values
data_y = raw_events.values

print(len(data_X))
display( data_X)
print(len(data_y))
display(data_y)
# Out:
# 284000
# array([[-19.73871407,  -5.18264522, -35.1313386 , ...,  -5.18264522,
#         -24.92535929, -28.27158202],
#        [-17.22904703,   8.03493454, -23.0849368 , ...,   4.52140068,
#         -29.44275997, -21.74644771],
#        [-11.37315726,  19.4120918 , -16.89442476, ...,  11.5484684 ,
#         -28.60620429, -14.55206885],
#        ...,
#        [-28.94082656, -25.92922611, -35.96789428, ..., -29.61007111,
#         -34.79671633, -24.59073702],
#        [-27.43502634, -26.09653725, -39.31411701, ..., -30.61393793,
#         -46.84311814, -20.90989203],
#        [-21.2445143 , -24.08880361, -27.93695975, ..., -28.77351543,
#         -39.31411701, -22.08106998]])
# 284000
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Extacts the timestamps where a seizure is present
seizure_index = raw_events[raw_events == 1].index

#np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(threshold=20)

seizure_index.values
# Out:
# array([544.98 , 544.984, 544.988, ..., 664.108, 664.112, 664.116])

# %%
for index, val in raw_events.iteritems():
    if(val == 1):
        print(index, val)
        break
# Out:
# 544.98 1

# %%
interictal = []
ictal = []

count = 0
for index, row in raw_data.iterrows():
    if(index in seizure_index):
        #print(index)
        #print(row.values)
        ictal.append(row.values)
        #ictal = np.vstack([ictal, row.values])
    else:
        interictal.append(row.values)
        
interictal_np = np.array(interictal)
ictal_np = np.array(ictal)

# %%
np.set_printoptions(threshold=20)

print(ictal_np)
print(len(ictal_np))
# Out:
# [[  8.53686795 -20.40795862 -24.08880361 ... -21.41182543 -16.39249135
#   -16.22518021]
#  [ -5.01533409 -27.43502634 -26.26384838 ... -25.92922611 -14.71937999
#   -15.22131339]
#  [-13.8828243  -25.4272927  -26.26384838 ... -26.93309293 -19.23678066
#   -15.89055794]
#  ...
#  [-15.38862453 -26.26384838  -6.0192009  ... -17.73098044 -25.25998157
#    -9.86735704]
#  [-16.39249135 -23.75418134  -0.83255568 ... -19.06946953 -22.91762566
#   -11.70777953]
#  [-17.22904703 -18.73484725   1.50980023 ... -20.74258089 -19.90602521
#   -14.88669112]]
# 29785

# %%
'''
    MAtrix form
'''
WINDOW_LENGTH = 20 # in seconds 
WINDOW_LENGTH_MS = WINDOW_LENGTH * 250

interictal_train = []
ictal_train = []

y_train = []

# Interictal train
for i in range(100):
    end_index = random.randint(WINDOW_LENGTH_MS, len(interictal_np))
    start_index = end_index - WINDOW_LENGTH_MS

    interictal_train.append(interictal_np[start_index:end_index])
    y_train.append([0])

# Ictal train
for i in range(100):
    end_index = random.randint(WINDOW_LENGTH_MS, len(ictal_np))
    start_index = end_index - WINDOW_LENGTH_MS

    ictal_train.append(ictal_np[start_index:end_index])
    y_train.append([1])

interictal_test = []
ictal_test = []

y_test = []

# Interictal test
for i in range(50):
    end_index = random.randint(WINDOW_LENGTH_MS, len(interictal_np))
    start_index = end_index - WINDOW_LENGTH_MS
    
    interictal_test.append(interictal_np[start_index:end_index])
    y_test.append([0])

# Ictal test
for i in range(50):
    end_index = random.randint(WINDOW_LENGTH_MS, len(ictal_np))
    start_index = end_index - WINDOW_LENGTH_MS
    
    ictal_test.append(ictal_np[start_index:end_index])
    y_test.append([1])

# %%
WINDOW_LENGTH = 20 # in seconds 
WINDOW_LENGTH_MS = WINDOW_LENGTH * 250

interictal_train = []
ictal_train = []

y_train = []

# Interictal train
for i in range(100):
    end_index = random.randint(WINDOW_LENGTH_MS, len(interictal_np))
    start_index = end_index - WINDOW_LENGTH_MS

    interictal_train.append(interictal_np[start_index:end_index].flatten())
    y_train.append([0])

# Ictal train
for i in range(100):
    end_index = random.randint(WINDOW_LENGTH_MS, len(ictal_np))
    start_index = end_index - WINDOW_LENGTH_MS

    ictal_train.append(ictal_np[start_index:end_index].flatten())
    y_train.append([1])

interictal_test = []
ictal_test = []

y_test = []

# Interictal test
for i in range(50):
    end_index = random.randint(WINDOW_LENGTH_MS, len(interictal_np))
    start_index = end_index - WINDOW_LENGTH_MS
    
    interictal_test.append(interictal_np[start_index:end_index].flatten())
    y_test.append([0])

# Ictal test
for i in range(50):
    end_index = random.randint(WINDOW_LENGTH_MS, len(ictal_np))
    start_index = end_index - WINDOW_LENGTH_MS
    
    ictal_test.append(ictal_np[start_index:end_index].flatten())
    y_test.append([1])

# %%
X_train = interictal_train + ictal_train

print(len(X_train))
print(X_train[0])

X_test = interictal_test + ictal_test
# Out:
# 200
# [ -0.33062227 -27.43502634  -7.8596234  ... -12.54433522  -4.51340068
#  -17.22904703]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)


print(X_train.shape)
print(y_train.shape)
# Out:
# (200, 95000)
# (200, 1)

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    # 100 neuron hidden layer
    tf.keras.layers.Dense(100, activation='relu', input_shape=(1,WINDOW_LENGTH_MS*19)),
    
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 'interictal' and 1 for 'ictal'
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1, 100)            9500100
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 1)              101
# =================================================================
# Total params: 9,500,201
# Trainable params: 9,500,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 50

from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

best_model_filepath = "Best_Model.ckpt"

# Save the model under certain conditions
callback_checkpoint = ModelCheckpoint(filepath=best_model_filepath,
                                      monitor='val_loss',
                                      verbose=0,
                                      save_weights_only=True,
                                      save_best_only=True)


callback_early_stopping = EarlyStopping(monitor='val_loss',
                                        patience=5, 
                                        verbose=1)

def create_callbacks(best_model_filepath):

    callback_checkpoint = ModelCheckpoint(filepath=best_model_filepath,
                                        monitor='val_loss',
                                        verbose=0,
                                        save_weights_only=True,
                                        save_best_only=True)
  
    callback_early_stopping = EarlyStopping(monitor='val_loss',
                                        patience=5, 
                                        verbose=1)

# %%
from tensorflow.keras.optimizers import Adam

model.compile(optimizer=Adam(0.001),
              loss='binary_crossentropy',
              metrics=['accuracy', 'AUC', 'Recall', 'Precision'])

# %%
EPOCHS = 50
BATCH_SIZE = 64

history = model.fit(X_train, 
                    y_train,
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_split=0.1,
                    callbacks= create_callbacks(best_model_filepath),
                    verbose=1)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 1, 95000) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 95000), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 95000).
# WARNING:tensorflow:Model was constructed with shape (None, 1, 95000) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 95000), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 95000).
# 3/3 [==============================] - ETA: 0s - loss: 237.7133 - accuracy: 0.4729 - auc: 0.4820 - recall: 0.3577 - precision: 0.3720WARNING:tensorflow:Model was constructed with shape (None, 1, 95000) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 95000), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 95000).
# 3/3 [==============================] - 3s 957ms/step - loss: 288.0845 - accuracy: 0.4769 - auc: 0.4866 - recall: 0.3808 - precision: 0.3862 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 2/50
# 3/3 [==============================] - 0s 92ms/step - loss: 501.7381 - accuracy: 0.4977 - auc: 0.5234 - recall: 0.8625 - precision: 0.4719 - val_loss: 1629.8599 - val_accuracy: 0.0000e+00 - val_auc: 0.0000e+00 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 3/50
# 3/3 [==============================] - 0s 101ms/step - loss: 520.4251 - accuracy: 0.5778 - auc: 0.5588 - recall: 0.1312 - precision: 0.4375 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 4/50
# 3/3 [==============================] - 0s 112ms/step - loss: 171.1433 - accuracy: 0.5898 - auc: 0.6308 - recall: 1.0000 - precision: 0.5278 - val_loss: 368.1845 - val_accuracy: 0.0000e+00 - val_auc: 0.0000e+00 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 5/50
# 3/3 [==============================] - 0s 100ms/step - loss: 113.0197 - accuracy: 0.6844 - auc: 0.6241 - recall: 0.2483 - precision: 1.0000 - val_loss: 63.4327 - val_accuracy: 0.5000 - val_auc: 0.0000e+00 - val_recall: 0.5000 - val_precision: 1.0000
# Epoch 6/50
# 3/3 [==============================] - 0s 105ms/step - loss: 31.3061 - accuracy: 0.8164 - auc: 0.8248 - recall: 0.9171 - precision: 0.7605 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 7/50
# 3/3 [==============================] - 0s 101ms/step - loss: 29.4216 - accuracy: 0.8023 - auc: 0.8273 - recall: 0.9563 - precision: 0.6997 - val_loss: 356.2033 - val_accuracy: 0.0000e+00 - val_auc: 0.0000e+00 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 8/50
# 3/3 [==============================] - 0s 98ms/step - loss: 53.9180 - accuracy: 0.7463 - auc: 0.7373 - recall: 0.4500 - precision: 1.0000 - val_loss: 47.0381 - val_accuracy: 0.5000 - val_auc: 0.0000e+00 - val_recall: 0.5000 - val_precision: 1.0000
# Epoch 9/50
# 3/3 [==============================] - 0s 98ms/step - loss: 3.4762 - accuracy: 0.9589 - auc: 0.9637 - recall: 1.0000 - precision: 0.9159 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 10/50
# 3/3 [==============================] - 0s 97ms/step - loss: 26.9151 - accuracy: 0.8209 - auc: 0.8544 - recall: 1.0000 - precision: 0.7009 - val_loss: 76.8412 - val_accuracy: 0.5000 - val_auc: 0.0000e+00 - val_recall: 0.5000 - val_precision: 1.0000
# Epoch 11/50
# 3/3 [==============================] - 0s 99ms/step - loss: 2.6253 - accuracy: 0.9675 - auc: 0.9634 - recall: 0.9267 - precision: 1.0000 - val_loss: 197.6867 - val_accuracy: 0.2000 - val_auc: 0.0000e+00 - val_recall: 0.2000 - val_precision: 1.0000
# Epoch 12/50
# 3/3 [==============================] - 0s 107ms/step - loss: 2.8756 - accuracy: 0.9705 - auc: 0.9660 - recall: 0.9320 - precision: 1.0000 - val_loss: 62.0941 - val_accuracy: 0.5000 - val_auc: 0.0000e+00 - val_recall: 0.5000 - val_precision: 1.0000
# Epoch 13/50
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0948 - accuracy: 0.9972 - auc: 0.9975 - recall: 1.0000 - precision: 0.9938 - val_loss: 0.2923 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 14/50
# 3/3 [==============================] - 0s 101ms/step - loss: 0.7776 - accuracy: 0.9827 - auc: 0.9843 - recall: 1.0000 - precision: 0.9632 - val_loss: 1.5611e-26 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 15/50
# 3/3 [==============================] - 0s 103ms/step - loss: 0.4245 - accuracy: 0.9866 - auc: 0.9880 - recall: 1.0000 - precision: 0.9706 - val_loss: 2.9284e-24 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 16/50
# 3/3 [==============================] - 0s 98ms/step - loss: 6.4862e-12 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 4.4043e-18 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 17/50
# 3/3 [==============================] - 0s 99ms/step - loss: 1.2028e-30 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 1.9053e-13 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 18/50
# 3/3 [==============================] - 0s 102ms/step - loss: 2.1760e-35 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 5.6951e-10 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 19/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.2813e-07 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 20/50
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 2.0190e-05 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 21/50
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 5.7254e-04 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 22/50
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 23/50
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.0323 - val_accuracy: 1.0000 - val_auc: 0.0000e+00 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 24/50
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 25/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 26/50
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 27/50
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.1849 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 28/50
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 29/50
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2213 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 30/50
# 3/3 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2329 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 31/50
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2415 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 32/50
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2479 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 33/50
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2527 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 34/50
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2562 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 35/50
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 36/50
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2607 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 37/50
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2622 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 38/50
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2632 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 39/50
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 40/50
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 41/50
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 42/50
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 43/50
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 44/50
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 45/50
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2659 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 46/50
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2660 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 47/50
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2660 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 48/50
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 49/50
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000
# Epoch 50/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - auc: 1.0000 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9500 - val_auc: 0.0000e+00 - val_recall: 0.9500 - val_precision: 1.0000

# %%
import matplotlib.pyplot as plt

def plot_progress(history_dict):
  for key in list(history_dict.keys())[:5]:
    plt.clf() # Clears the figure
    training_values = history_dict[key] 
    val_values = history_dict['val_'+key]

    epochs = range(1, len(training_values) + 1)

    plt.plot(epochs, training_values, 'bo', label='Training '+key)

    plt.plot(epochs, val_values, 'b', label='Validation '+key)

    if key != 'loss':
      plt.ylim([0.,1.1])

    plt.title('Training and Validation '+key) 
    plt.xlabel('Epochs')
    plt.ylabel(key)
    plt.legend()
    plt.show()
    
plot_progress(history.history)
